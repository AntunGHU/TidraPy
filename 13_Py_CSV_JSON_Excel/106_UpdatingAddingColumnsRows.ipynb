# %%
import pandas
df1=pandas.read_csv('supermarkets2.csv', header=None) # Kolone dobijaju nazive brojeve sto je bitno jer u situaciji kad fajl nema header-a on prvi red promovira u header i tako taj red ispada iz kalkulacija! Vidi donju celiju!
df1.columns = ["red", "adr", "grad", "posta", "drzava", "Trgov", "kom"]
df1
# Out:
#    red              adr           grad             posta drzava        Trgov  \
# 0    1     3666 21st St  San Francisco          CA 94114    USA      Madeira
# 1    2   735 Dolores St  San Francisco          CA 94119    USA  Bready Shop
# 2    3      332 Hill St  San Francisco  California 94114    USA  Super River
# 3    4     3995 23rd St  San Francisco          CA 94114    USA   Ben's Shop
# 4    5  1056 Sanchez St  San Francisco        California    USA      Sanchez
# 5    6  551 Alvarado St  San Francisco          CA 94114    USA   Richvalley
#
#    kom
# 0    8
# 1   15
# 2   25
# 3   10
# 4   12
# 5   20

# %%
# imali svoje indeksiranje redova (kao gore kolona red), ili ne imali, pandas svejedno redove indeksira po svom. Ako zelimo sami indeksirati:
df2 = df1.set_index("red")

# %%
df1     # dokaz da df1 nije mjenjan in place zbog cega smo i snimali u varijablu df2
# Out:
#    red              adr           grad             posta drzava        Trgov  \
# 0    1     3666 21st St  San Francisco          CA 94114    USA      Madeira
# 1    2   735 Dolores St  San Francisco          CA 94119    USA  Bready Shop
# 2    3      332 Hill St  San Francisco  California 94114    USA  Super River
# 3    4     3995 23rd St  San Francisco          CA 94114    USA   Ben's Shop
# 4    5  1056 Sanchez St  San Francisco        California    USA      Sanchez
# 5    6  551 Alvarado St  San Francisco          CA 94114    USA   Richvalley
#
#    kom
# 0    8
# 1   15
# 2   25
# 3   10
# 4   12
# 5   20

# %%
df2 # red je presao u posebni red-naziv i ispod rastuci brojevi preostalih redova
# Out:
#                  adr           grad             posta drzava        Trgov  kom
# red
# 1       3666 21st St  San Francisco          CA 94114    USA      Madeira    8
# 2     735 Dolores St  San Francisco          CA 94119    USA  Bready Shop   15
# 3        332 Hill St  San Francisco  California 94114    USA  Super River   25
# 4       3995 23rd St  San Francisco          CA 94114    USA   Ben's Shop   10
# 5    1056 Sanchez St  San Francisco        California    USA      Sanchez   12
# 6    551 Alvarado St  San Francisco          CA 94114    USA   Richvalley   20

# %%
len(df2.index)
# Out:
# 6

# %%
df2["Continent"]=df2.shape[0]*["SjAmerika"] # dodajem kolonu [0], * ispuna, SjAmerika -sadrzaj 
df2 # inplace
# Out:
#                  adr           grad             posta drzava        Trgov  \
# red
# 1       3666 21st St  San Francisco          CA 94114    USA      Madeira
# 2     735 Dolores St  San Francisco          CA 94119    USA  Bready Shop
# 3        332 Hill St  San Francisco  California 94114    USA  Super River
# 4       3995 23rd St  San Francisco          CA 94114    USA   Ben's Shop
# 5    1056 Sanchez St  San Francisco        California    USA      Sanchez
# 6    551 Alvarado St  San Francisco          CA 94114    USA   Richvalley
#
#      kom  Continent
# red
# 1      8  SjAmerika
# 2     15  SjAmerika
# 3     25  SjAmerika
# 4     10  SjAmerika
# 5     12  SjAmerika
# 6     20  SjAmerika

# %%
df2.shape       # daje tupl kojem je prvi el. br redova, a drugi br kolona
# Out:
# (6, 7)

# %%
df2.shape[0]      # pozivam 1 el tupla
# Out:
# 6

# %%
df2.shape[0]*["SjAm"]     # pozivam 1 el tupla-redove i mnozim sa Stringom "SjAm"
# Out:
# ['SjAm', 'SjAm', 'SjAm', 'SjAm', 'SjAm', 'SjAm']

# %%
df2["Continent"]=df2["drzava"] + "," + "SjAm" #Modifikacija sadrzaja
df2
# Out:
#                  adr           grad             posta drzava        Trgov  \
# red
# 1       3666 21st St  San Francisco          CA 94114    USA      Madeira
# 2     735 Dolores St  San Francisco          CA 94119    USA  Bready Shop
# 3        332 Hill St  San Francisco  California 94114    USA  Super River
# 4       3995 23rd St  San Francisco          CA 94114    USA   Ben's Shop
# 5    1056 Sanchez St  San Francisco        California    USA      Sanchez
# 6    551 Alvarado St  San Francisco          CA 94114    USA   Richvalley
#
#      kom Continent
# red
# 1      8  USA,SjAm
# 2     15  USA,SjAm
# 3     25  USA,SjAm
# 4     10  USA,SjAm
# 5     12  USA,SjAm
# 6     20  USA,SjAm

# %%
df2_t=df2.T     # Transpozicija tabele kao priprema za dodavanje reda
df2_t
# Out:
# red                    1               2                 3              4  \
# adr         3666 21st St  735 Dolores St       332 Hill St   3995 23rd St
# grad       San Francisco   San Francisco     San Francisco  San Francisco
# posta           CA 94114        CA 94119  California 94114       CA 94114
# drzava               USA             USA               USA            USA
# Trgov            Madeira     Bready Shop       Super River     Ben's Shop
# kom                    8              15                25             10
# Continent       USA,SjAm        USA,SjAm          USA,SjAm       USA,SjAm
#
# red                      5                6
# adr        1056 Sanchez St  551 Alvarado St
# grad         San Francisco    San Francisco
# posta           California         CA 94114
# drzava                 USA              USA
# Trgov              Sanchez       Richvalley
# kom                     12               20
# Continent         USA,SjAm         USA,SjAm

# %%
df2_t["MyAAAAA"]=["myadr", "mojgrad", "mojaposta", "moja drzava", "mojatrg", 30, "Evropa"]
df2_t
# Out:
# red                    1               2                 3              4  \
# adr         3666 21st St  735 Dolores St       332 Hill St   3995 23rd St
# grad       San Francisco   San Francisco     San Francisco  San Francisco
# posta           CA 94114        CA 94119  California 94114       CA 94114
# drzava               USA             USA               USA            USA
# Trgov            Madeira     Bready Shop       Super River     Ben's Shop
# kom                    8              15                25             10
# Continent       USA,SjAm        USA,SjAm          USA,SjAm       USA,SjAm
#
# red                      5                6      MyAAAAA
# adr        1056 Sanchez St  551 Alvarado St        myadr
# grad         San Francisco    San Francisco      mojgrad
# posta           California         CA 94114    mojaposta
# drzava                 USA              USA  moja drzava
# Trgov              Sanchez       Richvalley      mojatrg
# ...

# %%
df2=df2_t.T     # vracamo na pravo orginalno novim transpom
df2
# Out:
#                      adr           grad             posta       drzava  \
# red
# 1           3666 21st St  San Francisco          CA 94114          USA
# 2         735 Dolores St  San Francisco          CA 94119          USA
# 3            332 Hill St  San Francisco  California 94114          USA
# 4           3995 23rd St  San Francisco          CA 94114          USA
# 5        1056 Sanchez St  San Francisco        California          USA
# 6        551 Alvarado St  San Francisco          CA 94114          USA
# MyAAAAA            myadr        mojgrad         mojaposta  moja drzava
#
#                Trgov kom Continent
# red
# 1            Madeira   8  USA,SjAm
# 2        Bready Shop  15  USA,SjAm
# 3        Super River  25  USA,SjAm
# 4         Ben's Shop  10  USA,SjAm
# 5            Sanchez  12  USA,SjAm
# 6         Richvalley  20  USA,SjAm
# MyAAAAA      mojatrg  30    Evropa

# %%
df2_t[6]=["myadr", "mojgrad", "mojaposta", "moja drzava", "mojatrg", 30, "Evropa"] # modifikacija postojeceg reda 6 isto kao i pri kreiranju novog MyAAAAA
df2=df2_t.T
df2
# Out:
#                      adr           grad             posta       drzava  \
# red
# 1           3666 21st St  San Francisco          CA 94114          USA
# 2         735 Dolores St  San Francisco          CA 94119          USA
# 3            332 Hill St  San Francisco  California 94114          USA
# 4           3995 23rd St  San Francisco          CA 94114          USA
# 5        1056 Sanchez St  San Francisco        California          USA
# 6                  myadr        mojgrad         mojaposta  moja drzava
# MyAAAAA            myadr        mojgrad         mojaposta  moja drzava
#
#                Trgov kom Continent
# red
# 1            Madeira   8  USA,SjAm
# 2        Bready Shop  15  USA,SjAm
# 3        Super River  25  USA,SjAm
# 4         Ben's Shop  10  USA,SjAm
# 5            Sanchez  12  USA,SjAm
# 6            mojatrg  30    Evropa
# MyAAAAA      mojatrg  30    Evropa
